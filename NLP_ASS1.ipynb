# %%
# !pip install nltk
import nltk
from nltk.tokenize import word_tokenize

# Download the required NLTK data
nltk.download('punkt')
# Out:
# Requirement already satisfied: nltk in /usr/local/lib/python3.10/dist-packages (3.8.1)
# Requirement already satisfied: click in /usr/local/lib/python3.10/dist-packages (from nltk) (8.1.7)
# Requirement already satisfied: joblib in /usr/local/lib/python3.10/dist-packages (from nltk) (1.3.2)
# Requirement already satisfied: regex>=2021.8.3 in /usr/local/lib/python3.10/dist-packages (from nltk) (2023.12.25)
# Requirement already satisfied: tqdm in /usr/local/lib/python3.10/dist-packages (from nltk) (4.66.2)
# [nltk_data] Downloading package punkt to /root/nltk_data...
# [nltk_data]   Unzipping tokenizers/punkt.zip.
# True

# %%
nltk.download('wordnet')
nltk.download('stopwords')
# Out:
# [nltk_data] Downloading package wordnet to /root/nltk_data...
# [nltk_data]   Package wordnet is already up-to-date!
# [nltk_data] Downloading package stopwords to /root/nltk_data...
# [nltk_data]   Unzipping corpora/stopwords.zip.
# True

# %%
import requests
from bs4 import BeautifulSoup
import re
from nltk.tokenize import word_tokenize
from nltk.corpus import stopwords
from nltk.stem import WordNetLemmatizer

# %%
# Step 1: Extract HTML from URL
url = "https://en.wikipedia.org/wiki/Python_(programming_language)"
response = requests.get(url)
html = response.text

# %%
# Step 2: Extract TEXT from HTML page
text = ""
for paragraph in soup.find_all(["p", "h1", "h2", "h3", "h4", "h5", "h6"]):
    text += paragraph.get_text()

# %%
# Step 3: Processing on Data
# 1. Cleaning data
text = re.sub(r"[^a-zA-Z\s]", "", text)

# 2. Normalization: Convert to lowercase
text = text.lower()

# 3. Tokenization: Split the data into words
words = word_tokenize(text)

# %%
# 4. Lemmatization
lemmatizer = WordNetLemmatizer()
words = [lemmatizer.lemmatize(word) for word in words]

# 5. Remove stop words
stop_words = set(stopwords.words("english"))
filtered_words = [word for word in words if word not in stop_words]

# Unique Word: Get all unique words
unique_words = set(filtered_words)

# Print unique words
print("Unique words:")
for word in unique_words:
    print(word)
# Out:
# Unique words:
# normal
# december
# science
# union
# difficult
# web
# syntactic
# structure
# doxygen
# erlang
# coding
# opencv
# disallowed
# generating
# multiple
# add
# specific
# relation
# september
# describing
# script
# modify
# methodseditmethods
# study
# collecting
# define
# ability
# tkinter
# gui
# dcgs
# w
# originally
# spamclass
# motto
# foundation
# cern
# historyeditpython
# django
# material
# classic
# gpt
# translation
# drop
# understand
# provided
# three
# compared
# future
# ie
# top
# advantage
# earlier
# semanticseditpython
# began
# worse
# november
# emulated
# rossums
# instead
# amigaos
# generatorsedittools
# theory
# reflection
# requiring
# wsgi
# monitor
# providing
# domainspecific
# laptop
# lot
# mime
# body
# suitable
# c
# revision
# retention
# final
# part
# variable
# max
# fluency
# metaprogramming
# aid
# mixture
# title
# numpy
# twisted
# among
# pep
# sugar
# gateway
# bytecode
# conference
# help
# answering
# used
# justintime
# lightwave
# preferably
# ahead
# project
# building
# enjoyed
# two
# ironpython
# tail
# formatting
# bug
# etc
# install
# match
# fix
# librarieseditpythons
# tiobe
# adopted
# frequently
# interval
# implemented
# many
# experimental
# system
# fixed
# featureseditpython
# extension
# usually
# cpython
# full
# natural
# emphasis
# readable
# workload
# metasyntactic
# prefix
# preview
# popularityeditsince
# pypi
# need
# meant
# pygame
# input
# sagemath
# computing
# unixlike
# search
# possible
# bara
# objectivec
# received
# visual
# conceived
# argument
# entity
# considered
# decision
# update
# year
# poisoning
# popular
# standard
# versionseg
# major
# intelligence
# modularity
# occasionally
# existing
# lesscluttered
# suite
# sdl
# query
# changed
# patch
# reporting
# github
# utility
# binding
# widespread
# avoid
# read
# official
# presented
# earliest
# learning
# arbitrary
# generator
# element
# wikipedia
# capablities
# produce
# duck
# unintended
# database
# line
# capable
# diffusion
# distributed
# syntax
# response
# coroutinelike
# lie
# condition
# execution
# special
# programmer
# typed
# machine
# developing
# select
# userprogramming
# dynamic
# semantic
# pycharm
# creator
# remainder
# compiled
# handled
# receive
# tiebreaking
# knowledge
# clause
# user
# available
# definite
# borrowed
# rossum
# schedule
# permanent
# curly
# ab
# even
# equation
# manner
# forwardported
# maintenance
# minimalist
# ranked
# shop
# modified
# container
# automates
# statement
# extensive
# compiler
# altering
# also
# probably
# newstyle
# high
# conform
# problog
# last
# idle
# method
# recent
# houdini
# rational
# different
# provide
# studio
# might
# following
# small
# regular
# rank
# java
# constructed
# boolean
# continuation
# benchmark
# rewriting
# pas
# endoflife
# namea
# enforced
# implementationseditunsupported
# haskell
# error
# vacation
# pypy
# functools
# implement
# mistaking
# constraint
# emphasizing
# doubleunderscores
# however
# conducted
# information
# objectoriented
# clever
# complex
# wsgiref
# pythonanywhere
# httpservercgihttprequesthandler
# lead
# forum
# proposing
# procedural
# access
# come
# according
# including
# bab
# passed
# literature
# selected
# perls
# softimage
# gentoo
# matplotlib
# languageseditthere
# another
# highlevel
# prolog
# martelli
# proposal
# whether
# call
# modwsgi
# distinction
# release
# oldest
# paradigm
# strongly
# written
# amoeba
# corresponds
# staticallytyped
# operator
# capability
# source
# security
# platform
# useful
# object
# wiskunde
# officially
# class
# infix
# equality
# book
# speed
# embrace
# highly
# sqlalchemy
# interface
# swift
# group
# later
# offer
# related
# intends
# subsequently
# game
# wstr
# ha
# result
# biopython
# lambda
# pythondev
# primary
# doe
# floatingpoint
# noncritical
# permitting
# academic
# ita
# successor
# unicode
# exponentiation
# typingnamedtuple
# bottle
# deprecated
# soft
# work
# deprecationwarning
# apple
# february
# principle
# new
# musical
# application
# expected
# simple
# task
# promotes
# ides
# annotation
# reddit
# setl
# rounding
# compiles
# alpha
# deliberately
# ml
# replace
# library
# represents
# cderived
# summarized
# delayed
# precision
# operation
# enter
# hosted
# speedup
# transcription
# untyped
# large
# bind
# validity
# attached
# covered
# releasecandidates
# indent
# develop
# modular
# compositor
# attempting
# designed
# contentspython
# roundup
# matching
# indentationeditpython
# rough
# infinity
# bracket
# turbogears
# control
# ctypes
# vitriol
# respectively
# initially
# flask
# factorial
# sequentially
# mypyc
# leverage
# mentoring
# expression
# culture
# installers
# several
# gnu
# nuke
# rationale
# fact
# consistently
# collection
# could
# never
# qt
# successfully
# tradition
# program
# wa
# place
# criticism
# name
# distinguished
# includes
# ai
# decimal
# floweditpythons
# form
# iterators
# commitment
# xp
# mailing
# mercurial
# rich
# ship
# freebsd
# thirdparty
# esri
# october
# cited
# compile
# one
# precedence
# scikitlearn
# doesnt
# team
# pdoc
# communication
# ready
# referred
# stack
# facebook
# particular
# hosting
# debugger
# ubuntu
# greatest
# programming
# calculus
# list
# guideline
# cycledetecting
# external
# singleboard
# show
# supported
# practice
# marginal
# module
# parameter
# interpret
# shell
# performance
# pyladies
# expressionso
# site
# language
# sole
# phase
# maya
# english
# opposite
# hat
# mypy
# crossplatform
# tool
# postponed
# sourcecode
# create
# specialized
# embedded
# rise
# adding
# end
# extensible
# methodology
# expressionseditpythons
# represent
# checked
# rigidly
# canopy
# webserver
# go
# ten
# size
# comedy
# moving
# distribution
# metaobjects
# crosscompilers
# notation
# readevalprint
# optional
# british
# facilitate
# unsupported
# tcl
# mathematics
# typical
# sketch
# gtk
# floor
# negative
# red
# premature
# pascal
# playful
# testing
# thus
# freecad
# engine
# alex
# working
# software
# effect
# added
# euroscipy
# algebra
# examplesedithello
# reference
# style
# repository
# outstanding
# ubiquity
# productive
# fewer
# operating
# accurately
# protocol
# include
# describe
# guido
# oneobvious
# virtual
# various
# discussed
# performanceeditperformance
# plus
# unit
# nature
# amazon
# decrease
# installer
# well
# behavior
# informatica
# length
# immediately
# pydoc
# logic
# message
# tensorflow
# improvement
# scheme
# inspired
# due
# contrast
# starting
# dropped
# towards
# process
# portability
# reaching
# bestowed
# allows
# aspect
# would
# design
# instance
# combination
# unary
# apache
# idiom
# emit
# scorewriter
# unofficial
# reject
# range
# index
# environment
# older
# representation
# back
# achieve
# pythonand
# zen
# solaris
# abaqus
# subset
# resolution
# separate
# significant
# increase
# documenting
# late
# rebound
# namingeditpythons
# differently
# structural
# notebook
# collector
# speedcritical
# fun
# typingeditpython
# simply
# extends
# espoused
# allowing
# feature
# oldstyle
# allowed
# latest
# surrounding
# maintaining
# either
# video
# kind
# mechanism
# delimit
# avoiding
# garbage
# tornado
# cinema
# regularly
# http
# raspberry
# chief
# clarity
# derived
# reflect
# connecting
# choice
# beginning
# ilm
# strength
# blender
# scribus
# lab
# scipy
# structured
# selfhosted
# easily
# recursive
# pythonistas
# netbsd
# wide
# calling
# provider
# found
# implementationeditcpython
# commonly
# effective
# round
# fedora
# stemmed
# currently
# approach
# something
# punctuation
# true
# term
# pseudorandom
# enhancement
# social
# instancemethodargument
# termed
# priority
# philosophy
# cwi
# rather
# level
# already
# division
# janus
# developed
# arithmetic
# commercial
# combinatorial
# modo
# active
# four
# bar
# sometimes
# useseditpython
# smaller
# beginneroriented
# others
# pattern
# optimization
# comparison
# processing
# internal
# artificial
# tracker
# predefined
# portage
# conditional
# remote
# current
# mostly
# counting
# aspectoriented
# lazy
# readability
# fully
# news
# firstclass
# nevertheless
# type
# longterm
# test
# command
# developer
# restricted
# indentation
# bb
# frustration
# per
# scripting
# pyjs
# calculate
# writing
# leading
# unlike
# denialofservice
# usual
# announced
# paint
# running
# responsibility
# reflected
# violate
# recommended
# explicit
# vms
# nasa
# macos
# arbitraryprecision
# finite
# signifies
# crosscompile
# january
# holder
# conventional
# fivemember
# time
# general
# least
# clientside
# best
# semantics
# mapper
# council
# battery
# functionality
# integer
# pyqt
# natlog
# insecure
# metaclass
# vision
# version
# exception
# improved
# unpythonic
# texttoimage
# extensively
# described
# x
# nearest
# mathrelated
# moved
# modeler
# float
# handling
# unrestricted
# dunder
# linux
# intellij
# whitespace
# made
# follows
# change
# literal
# evaluate
# environmentseditmost
# product
# industry
# relational
# benchmarked
# stable
# despite
# oneand
# b
# combinatorics
# aphorism
# generalpurpose
# simpler
# wrote
# pi
# centrum
# zope
# memory
# often
# see
# steering
# sense
# webpy
# text
# upon
# mac
# syntactically
# semicolon
# animation
# may
# pythonic
# dictionary
# continues
# contain
# server
# migrated
# spotify
# pythoneditpythons
# block
# expedited
# fellow
# framework
# dictator
# appear
# arcgis
# compact
# without
# eggsclass
# public
# scientific
# elected
# fails
# concern
# variant
# shouldered
# organization
# uncluttered
# py
# completely
# opposed
# set
# cpythons
# typingin
# interfacing
# operationseditpython
# consistency
# value
# networking
# array
# allocated
# every
# graphical
# evolved
# manipulation
# compilerstranspilers
# pytorch
# tutorial
# parametric
# neologism
# ide
# manipulating
# generate
# code
# bloat
# lisp
# data
# reviewed
# influenced
# released
# albeit
# valid
# involving
# exploit
# component
# issue
# ending
# alsoeditreferenceseditsourceseditfurther
# multiparadigm
# loop
# strive
# repl
# rating
# roundawayfromzero
# webcache
# allow
# dynamically
# routine
# backwardcompatible
# oftenused
# capella
# yahoo
# july
# community
# life
# specified
# itertools
# native
# implementationseditreference
# outdated
# documentation
# similar
# meaning
# discussion
# filtermapandreduce
# rule
# field
# typing
# empirical
# matrixmultiplication
# implementationseditother
# determined
# astropy
# main
# function
# better
# limited
# removed
# visually
# extending
# executed
# dropbox
# keywords
# claim
# duplicating
# us
# commented
# implementation
# pyramid
# increased
# cause
# mode
# potential
# programmable
# ipython
# implicit
# nonnumerical
# resigned
# pycon
# unidirectionally
# eg
# much
# included
# generic
# instagram
# conversion
# provides
# google
# document
# meeting
# python
# management
# app
# texttotext
# mean
# motionbuilder
# emphasizes
# idea
# although
# problem
# suited
# sphinx
# cost
# compliment
# incremented
# typeclass
# giving
# slightly
# numerical
# session
# core
# similarites
# catch
# controversial
# offside
# modulo
# window
# classmethodinstance
# make
# contains
# anaconda
# van
# package
# fork
# example
# state
# geospatial
# common
# highlighting
# unnecessary
# intermediate
# pro
# openbsd
# contract
# benevolent
# addition
# pylon
# using
# gimp
# keyword
# space
# twice
# modern
# development
# way
# support
# certainty
# world
# since
# done
# netherlands
# traditional
# halfopen
# forbidding
# attack
# called
# functional
# format
# math
# consistent
# integrated
# spam
# symbol
# aim
# architecture
# tribute
# ruby
# creating
# notable
# string
# possibly
# u
# imaging
# abc
# joining
# signifying
# consumption
# rarely
# june
# foo
# though
# fraction
# self
# grammar
# resulting
# assignment
# browserbased
# highest
# positive
# autocompletion
# took
# api
# ajaxbased
# xo
# decisionmaker
# via
# series
# inkscape
# case
# internetfacing
# image
# reasoning
# fail
# largely
# graphviz
# pretty
# backported
# serve
# desktop
# computer
# certain
# developmenteditpythons
# linksedit
# egg
# refers
# always
# number
# cover
# kera
# pygtk
# libreoffice
# comprehensive
# prompt
# proved
# comprehension
# beta
# use
# interpreter
# significantly
# denote
# printer
# particularly
# first
# like
# terminal
# dalle
# gained
# userdefined
# child
# monty
# readingeditexternal
# silently
# author
# faster
# garbagecollected
# specificationsfor
# section
# le
# welldefined
